# %% [markdown]
# # 靜態網頁的資料爬蟲策略
#
#
# * 了解靜態網頁的資料爬蟲策略
# * 認識適用於靜態網頁爬蟲的相關套件工具：Request
# * 認識適用於靜態網頁爬蟲的相關套件工具：BeatifulSoup

# %% [markdown]
# ## 作業目標
#
# 利用 Request + BeatifulSoup 爬取下列兩個網站內容並解析：
#
# 1. Dcared 網址： https://www.dcard.tw/f
# 2. 知乎： https://www.zhihu.com/explore
#
# 並且回答下面問題：
#
# 1. Request 取回之後該怎麼取出資料，資料型態是什麼？
# 2. 為什麼要使用 BeatifulSoup 處理？處理後的型態是什麼？
# 3. 觀察一下知乎回來的資料好像有點怪怪的，該怎麼解決？

# %% [markdown]
# ### 1. Dcard 網址： https://www.dcard.tw/f

# %%
import requests
import json
from bs4 import BeautifulSoup

# %%
url = 'https://www.dcard.tw/f'

headers = {
    'user-agent': 'Mozilla/5.0 (Windows NT 6.1; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/83.0.4103.116 Safari/537.36'
    , 'content-type': 'application/json'
}
r = requests.get(url, headers=headers)

r.encoding = 'utf-8'
print(r.text[0:3000])
print(type(r.text))
# Out:
# <!DOCTYPE html><html lang="zh-TW"><head prefix="og: http://ogp.me/ns#" itemscope="" itemType="https://schema.org/WebSite"><meta charSet="utf-8"/><meta http-equiv="X-UA-Compatible" content="IE=edge"/><meta name="viewport" content="width=device-width, initial-scale=1, minimum-scale=1"/><meta name="apple-mobile-web-app-status-bar-style" content="default"/><link href="https://fonts.googleapis.com/css2?family=Roboto:wght@400;500;700&amp;display=swap" rel="stylesheet"/><meta name="application-name" content="Dcard"/><meta name="apple-itunes-app" content="app-id=951353454"/><meta name="theme-color" content="#006aa6"/><meta name="mobile-web-app-capable" content="yes"/><meta name="apple-mobile-web-app-capable" content="yes"/><meta name="supported-color-schemes" content="light"/><meta property="fb:app_id" content="211628828926493"/><meta property="fb:pages" content="178875832200695,577748865730563,1333515469994506,619122564952487,804004803032067,178024805867764"/><meta property="al:ios:app_stor
# ...

# %%
print('Request 取回之後該怎麼取出資料，資料型態是什麼？ =>')

'''
抓回來的是HTML檔案，資料型態是文字型態，
如果不用套件的方式抓資料，可使用正則表達式的方式抓取。
'''
# Out:
# Request 取回之後該怎麼取出資料，資料型態是什麼？ =>
# '\n抓回來的是HTML檔案，資料型態是文字型態，\n如果不用套件的方式抓資料，可使用正則表達式的方式抓取。\n'

# %%
print('為什麼要使用 BeatifulSoup 處理？處理後的型態是什麼？ => ')

'''
Beautiful Soup 是一個 Python 的函式庫模組，
可以讓開發者僅須撰寫非常少量的程式碼，就可以快速解析網頁 HTML 碼，
從中翠取出使用者有興趣的資料、去蕪存菁，
降低網路爬蟲程式的開發門檻、加快程式撰寫速度。

bs4.BeautifulSoup
'''
soup = BeautifulSoup(r.text, "html5lib")
print(soup.prettify())
#print(type(soup))
# Out:
# 為什麼要使用 BeatifulSoup 處理？處理後的型態是什麼？ =>
# <!DOCTYPE html>
# <html lang="zh-TW">
#  <head itemscope="" itemtype="https://schema.org/WebSite" prefix="og: http://ogp.me/ns#">
#   <meta charset="utf-8"/>
#   <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
#   <meta content="width=device-width, initial-scale=1, minimum-scale=1" name="viewport"/>
#   <meta content="default" name="apple-mobile-web-app-status-bar-style"/>
#   <link href="https://fonts.googleapis.com/css2?family=Roboto:wght@400;500;700&amp;display=swap" rel="stylesheet"/>
#   <meta content="Dcard" name="application-name"/>
#   <meta content="app-id=951353454" name="apple-itunes-app"/>
#   <meta content="#006aa6" name="theme-color"/>
#   <meta content="yes" name="mobile-web-app-capable"/>
#   <meta content="yes" name="apple-mobile-web-app-capable"/>
#   <meta content="light" name="supported-color-schemes"/>
#   <meta content="211628828926493" property="fb:app_id"/>
# ...

# %%
print("--------------------------")
print(soup.div['id'])
print("--------------------------")
print(soup.find_all('div'))
print("--------------------------")
print(soup.find_all('div', class_='sc-1ccznvc-0'))
# Out:
# --------------------------
# __next
# --------------------------
# ...

# %%
import re

# 以正規表示法搜尋 class 屬性
b_tag = soup.find_all(class_=re.compile("^sc-1ccznvc-\d"))
print(b_tag)
# Out:
# [<div class="sc-1ccznvc-0 emWQsw"><div class="sc-1ccznvc-1 fXrMZE"><a class="sc-1h3w01r-0 cOWxiB" href="/f" title="Dcard"><img alt="Dcard" class="ezgous-0 ixTrsr" src="/_next/static/media/logo-2ef7b50901acaa284f36a0484329ec05.svg"/></a><div class="sc-18hjmuk-1 lgXNYK"><div class="sc-1ehu1w3-0 krYaWn"><form><label class="ih5c0o-0 jPisqW"><div class="ih5c0o-2 dBqPat"><input aria-label="搜尋" class="ih5c0o-4 hHuYAw sc-1ehu1w3-2 evDMiH" placeholder="搜尋" type="search" value=""/></div></label><button class="sc-1ehu1w3-3 bGWEMw" disabled="" title="搜尋" type="submit"><span class="sc-1rm1ozc-0 fwHxVQ sc-1ehu1w3-7 bvbdhI" fill="#fff" role="img" size="20"><svg viewBox="0 0 28 28"><path d="M22.9 21.2l-4.5-4.5A7.5 7.5 0 1017 18l4.5 4.5a.5.5 0 00.8 0l.5-.5a.5.5 0 000-.8zm-10.4-3.5a5.6 5.6 0 115.6-5.6 5.6 5.6 0 01-5.6 5.6z"></path></svg></span></button></form></div></div></div><div class="sc-1ccznvc-2 iDvOMF" role="navigation"><a class="sc-17x0g9b-0 hHrnvN sc-4hbl5y-0 kClVql" href="/signup" role="butt
# ...

# %% [markdown]
# ### 2. 知乎： https://www.zhihu.com/explore

# %%
url = 'https://www.zhihu.com/explore'
r = requests.get(url)
r.encoding = 'utf-8'

print(r.text[0:600])
# Out:
# <html>
# <head><title>400 Bad Request</title></head>
# <body bgcolor="white">
# <center><h1>400 Bad Request</h1></center>
# <hr><center>openresty</center>
# </body>
# </html>

# %% [markdown]
# ### 3. 觀察一下知乎回來的資料好像有點怪怪的，該怎麼解決？

# %%
import requests
url = 'https://www.zhihu.com/explore'

headers = {
    'user-agent': 'Mozilla/5.0 (Windows NT 6.1; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/83.0.4103.116 Safari/537.36'
    , 'content-type': 'application/json'
}
r = requests.get(url, headers=headers)

r.encoding = 'utf-8'
print(r.text[0:600])

'加上header處理'
# Out:
# <!doctype html>
# <html lang="zh" data-hairline="true" data-theme="light"><head><meta charSet="utf-8"/><title data-react-helmet="true">发现 - 知乎</title><meta name="viewport" content="width=device-width,initial-scale=1,maximum-scale=1"/><meta name="renderer" content="webkit"/><meta name="force-rendering" content="webkit"/><meta http-equiv="X-UA-Compatible" content="IE=edge,chrome=1"/><meta name="google-site-verification" content="FTeR0c8arOPKh8c5DYh_9uu98_zJbaWw53J-Sch9MTg"/><meta name="description" property="og:description" content="有问题，上知乎。知乎，可信赖的问答社区，以让每个人高效获得可信赖的解答为使命。知乎凭借认真、专业和友善的社区氛围，结构化、易获得的
# '加上header處理'
